# %% [markdown]
# <font color = black size = 10 >Capital Asset Pricing Model</font>

# %% [markdown]
# <font size = 4> Model definition and its parameters:</font>
# ![Screen%20Shot%202020-04-06%20at%2012.07.56%20AM.png](attachment:Screen%20Shot%202020-04-06%20at%2012.07.56%20AM.png)

# %% [markdown]
# <font size = 4> Rm </font>

# %%
from scipy import stats
stock_returns = [0.065, 0.0265, -0.0593, -0.001, 0.0346]
mkt_returns = [0.055, -0.09, -0.041, 0.045, 0.022]

# %%
beta, alpha, r, p, std_err = stats.linregress(stock_returns, mkt_returns)

# %%
print(" beta: {}\n alpha: {}\n r: {}\n p: {}\n std_err: {}\n".format(beta, alpha, r, p, std_err))
# Out:
#  beta: 0.5077431878770808
#  alpha: -0.008481900352462384
#  r: 0.38455905003823676
#  p: 0.5227155239089462
#  std_err: 0.7036705543221569

# %% [markdown]
# <font color = black size = 10 >Arbitrage Price Theory Model</font>

# %% [markdown]
# ![Screen%20Shot%202020-05-14%20at%209.45.58%20PM.png](attachment:Screen%20Shot%202020-05-14%20at%209.45.58%20PM.png)

# %%
import numpy as np
import statsmodels.api as sm
 # Generate some sample data
num_periods = 9
all_values = np.array([np.random.random(8) for i in range(num_periods)])
 # Filter the data
y_values = all_values[:, 0] # First column values as Y
x_values = all_values[:, 1:] # All other values as X
x_values = sm.add_constant(x_values) # Include the intercept
results = sm.OLS(y_values, x_values).fit() # Regress and fit the model

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     1.629
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):              0.541
# Time:                        02:36:09   Log-Likelihood:                 9.6996
# No. Observations:                   9   AIC:                            -3.399
# Df Residuals:                       1   BIC:                            -1.821
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7747      1.055      0.734      0.597     -12.632      14.181
# ...

# %%
print(results.params)
# Out:
# [ 0.77467829  1.11848111  0.16826744 -0.24288609 -0.90205252 -0.04904105
#   0.09603465 -1.22529023]
